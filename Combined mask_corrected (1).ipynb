# %%
# !pip install shapely
# !pip install geopandas
# !pip install rasterio
# !pip install gdown
# !pip install rasterstats
# !pip install geemap
# Out:
# Requirement already satisfied: shapely in c:\users\pauli\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: numpy>=1.14 in c:\users\pauli\anaconda3\lib\site-packages (from shapely) (1.24.3)
# Requirement already satisfied: geopandas in c:\users\pauli\anaconda3\lib\site-packages (0.14.1)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\pauli\anaconda3\lib\site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in c:\users\pauli\anaconda3\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\pauli\anaconda3\lib\site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\pauli\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\pauli\anaconda3\lib\site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\pauli\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: certifi in c:\users\pauli\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (2023.11.17)
# Requirement already satisfied: click~=8.0 in c:\users\pauli\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\pauli\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\pauli\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\pauli\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\pauli\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pauli\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pauli\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pauli\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\pauli\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (1.24.3)
# Requirement already satisfied: colorama in c:\users\pauli\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Requirement already satisfied: rasterio in c:\users\pauli\anaconda3\lib\site-packages (1.3.9)
# Requirement already satisfied: affine in c:\users\pauli\anaconda3\lib\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in c:\users\pauli\anaconda3\lib\site-packages (from rasterio) (22.1.0)
# Requirement already satisfied: certifi in c:\users\pauli\anaconda3\lib\site-packages (from rasterio) (2023.11.17)
# Requirement already satisfied: click>=4.0 in c:\users\pauli\anaconda3\lib\site-packages (from rasterio) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\pauli\anaconda3\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in c:\users\pauli\anaconda3\lib\site-packages (from rasterio) (1.24.3)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\pauli\anaconda3\lib\site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\pauli\anaconda3\lib\site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\pauli\anaconda3\lib\site-packages (from rasterio) (68.0.0)
# Requirement already satisfied: colorama in c:\users\pauli\anaconda3\lib\site-packages (from click>=4.0->rasterio) (0.4.6)
# Requirement already satisfied: pyparsing>=2.1.6 in c:\users\pauli\anaconda3\lib\site-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Requirement already satisfied: gdown in c:\users\pauli\anaconda3\lib\site-packages (4.7.1)
# Requirement already satisfied: filelock in c:\users\pauli\anaconda3\lib\site-packages (from gdown) (3.9.0)
# Requirement already satisfied: requests[socks] in c:\users\pauli\anaconda3\lib\site-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in c:\users\pauli\anaconda3\lib\site-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in c:\users\pauli\anaconda3\lib\site-packages (from gdown) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\pauli\anaconda3\lib\site-packages (from gdown) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pauli\anaconda3\lib\site-packages (from beautifulsoup4->gdown) (2.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pauli\anaconda3\lib\site-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pauli\anaconda3\lib\site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pauli\anaconda3\lib\site-packages (from requests[socks]->gdown) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pauli\anaconda3\lib\site-packages (from requests[socks]->gdown) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\pauli\anaconda3\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in c:\users\pauli\anaconda3\lib\site-packages (from tqdm->gdown) (0.4.6)
# Requirement already satisfied: rasterstats in c:\users\pauli\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: affine in c:\users\pauli\anaconda3\lib\site-packages (from rasterstats) (2.4.0)
# Requirement already satisfied: click>7.1 in c:\users\pauli\anaconda3\lib\site-packages (from rasterstats) (8.0.4)
# Requirement already satisfied: cligj>=0.4 in c:\users\pauli\anaconda3\lib\site-packages (from rasterstats) (0.7.2)
# Requirement already satisfied: fiona in c:\users\pauli\anaconda3\lib\site-packages (from rasterstats) (1.9.5)
# Requirement already satisfied: numpy>=1.9 in c:\users\pauli\anaconda3\lib\site-packages (from rasterstats) (1.24.3)
# Requirement already satisfied: rasterio>=1.0 in c:\users\pauli\anaconda3\lib\site-packages (from rasterstats) (1.3.9)
# Requirement already satisfied: simplejson in c:\users\pauli\anaconda3\lib\site-packages (from rasterstats) (3.19.2)
# Requirement already satisfied: shapely in c:\users\pauli\anaconda3\lib\site-packages (from rasterstats) (2.0.2)
# Requirement already satisfied: colorama in c:\users\pauli\anaconda3\lib\site-packages (from click>7.1->rasterstats) (0.4.6)
# Requirement already satisfied: attrs in c:\users\pauli\anaconda3\lib\site-packages (from rasterio>=1.0->rasterstats) (22.1.0)
# Requirement already satisfied: certifi in c:\users\pauli\anaconda3\lib\site-packages (from rasterio>=1.0->rasterstats) (2023.11.17)
# Requirement already satisfied: snuggs>=1.4.1 in c:\users\pauli\anaconda3\lib\site-packages (from rasterio>=1.0->rasterstats) (1.4.7)
# Requirement already satisfied: click-plugins in c:\users\pauli\anaconda3\lib\site-packages (from rasterio>=1.0->rasterstats) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\pauli\anaconda3\lib\site-packages (from rasterio>=1.0->rasterstats) (68.0.0)
# Requirement already satisfied: six in c:\users\pauli\anaconda3\lib\site-packages (from fiona->rasterstats) (1.16.0)
# Requirement already satisfied: pyparsing>=2.1.6 in c:\users\pauli\anaconda3\lib\site-packages (from snuggs>=1.4.1->rasterio>=1.0->rasterstats) (3.0.9)
# Requirement already satisfied: geemap in c:\users\pauli\anaconda3\lib\site-packages (0.29.6)
# Requirement already satisfied: bqplot in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (0.12.42)
# Requirement already satisfied: colour in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: earthengine-api>=0.1.347 in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (0.1.384)
# Requirement already satisfied: eerepr>=0.0.4 in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (0.0.4)
# Requirement already satisfied: folium>=0.13.0 in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (0.15.1)
# Requirement already satisfied: geocoder in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.17.0 in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (0.18.1)
# Requirement already satisfied: ipytree in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (3.7.2)
# Requirement already satisfied: numpy in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (1.24.3)
# Requirement already satisfied: pandas in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (2.0.3)
# Requirement already satisfied: plotly in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (5.9.0)
# Requirement already satisfied: pyperclip in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (1.8.2)
# Requirement already satisfied: pyshp>=2.1.3 in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (7.1.1)
# Requirement already satisfied: scooby in c:\users\pauli\anaconda3\lib\site-packages (from geemap) (0.9.2)
# Requirement already satisfied: google-cloud-storage in c:\users\pauli\anaconda3\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.14.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\pauli\anaconda3\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.111.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\pauli\anaconda3\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.25.2)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\pauli\anaconda3\lib\site-packages (from earthengine-api>=0.1.347->geemap) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\pauli\anaconda3\lib\site-packages (from earthengine-api>=0.1.347->geemap) (0.22.0)
# Requirement already satisfied: requests in c:\users\pauli\anaconda3\lib\site-packages (from earthengine-api>=0.1.347->geemap) (2.31.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\pauli\anaconda3\lib\site-packages (from folium>=0.13.0->geemap) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\pauli\anaconda3\lib\site-packages (from folium>=0.13.0->geemap) (3.1.2)
# Requirement already satisfied: xyzservices in c:\users\pauli\anaconda3\lib\site-packages (from folium>=0.13.0->geemap) (2022.9.0)
# Requirement already satisfied: ipywidgets in c:\users\pauli\anaconda3\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.0.4)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\pauli\anaconda3\lib\site-packages (from ipyleaflet>=0.17.0->geemap) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\pauli\anaconda3\lib\site-packages (from bqplot->geemap) (5.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pauli\anaconda3\lib\site-packages (from pandas->geemap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pauli\anaconda3\lib\site-packages (from pandas->geemap) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pauli\anaconda3\lib\site-packages (from pandas->geemap) (2023.3)
# Requirement already satisfied: click in c:\users\pauli\anaconda3\lib\site-packages (from geocoder->geemap) (8.0.4)
# Requirement already satisfied: future in c:\users\pauli\anaconda3\lib\site-packages (from geocoder->geemap) (0.18.3)
# Requirement already satisfied: ratelim in c:\users\pauli\anaconda3\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\users\pauli\anaconda3\lib\site-packages (from geocoder->geemap) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pauli\anaconda3\lib\site-packages (from matplotlib->geemap) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\pauli\anaconda3\lib\site-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pauli\anaconda3\lib\site-packages (from matplotlib->geemap) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pauli\anaconda3\lib\site-packages (from matplotlib->geemap) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pauli\anaconda3\lib\site-packages (from matplotlib->geemap) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pauli\anaconda3\lib\site-packages (from matplotlib->geemap) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\pauli\anaconda3\lib\site-packages (from matplotlib->geemap) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\pauli\anaconda3\lib\site-packages (from plotly->geemap) (8.2.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\pauli\anaconda3\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (2.15.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\pauli\anaconda3\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\pauli\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\pauli\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\pauli\anaconda3\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (4.9)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\pauli\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.25.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\pauli\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.15.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\pauli\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\pauli\anaconda3\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pauli\anaconda3\lib\site-packages (from jinja2>=2.9->folium>=0.13.0->geemap) (2.1.1)
# Requirement already satisfied: colorama in c:\users\pauli\anaconda3\lib\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\pauli\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.6.0 in c:\users\pauli\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap) (2.7.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\pauli\anaconda3\lib\site-packages (from google-cloud-storage->earthengine-api>=0.1.347->geemap) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pauli\anaconda3\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pauli\anaconda3\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pauli\anaconda3\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pauli\anaconda3\lib\site-packages (from requests->earthengine-api>=0.1.347->geemap) (2023.11.17)
# Requirement already satisfied: decorator in c:\users\pauli\anaconda3\lib\site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\pauli\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (1.62.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in c:\users\pauli\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=0.1.347->geemap) (4.25.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\pauli\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\pauli\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\pauli\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\pauli\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\pauli\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\pauli\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.5.6)
# Requirement already satisfied: psutil in c:\users\pauli\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\pauli\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\pauli\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (6.3.2)
# Requirement already satisfied: backcall in c:\users\pauli\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\pauli\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\pauli\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\pauli\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\pauli\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\pauli\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\pauli\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.347->geemap) (0.4.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\pauli\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\pauli\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\pauli\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\pauli\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->ipyfilechooser>=0.6.0->geemap) (305.1)
# Requirement already satisfied: wcwidth in c:\users\pauli\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.5)
# Requirement already satisfied: executing in c:\users\pauli\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\pauli\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\pauli\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)

# %%
import geemap, ee
import pandas as pd
import geopandas as gpd
import importlib
import sys
import subprocess
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ee.Authenticate()
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Create a map
Map = geemap.Map()

# Define the coordinates and zoom level for the region of interest (ROI)
roi_longitude = 26.8
roi_latitude = 37.8
zoom_level = 11

# Define the Area of Interest (AOI) as a Polygon.
AOI = ee.Geometry.Polygon([[27.099800633717916,37.75135777501414],
[27.099800633717916,37.89454805937824],
[26.55185751848354,37.89454805937824],
[26.55185751848354,37.75135777501414]])
AOI

# Define the study area and date range
study_area = ee.Geometry.Point(roi_longitude, roi_latitude)
start_date = '2023-04-01'
end_date = '2023-07-01'

# Center the map on the ROI
Map.setCenter(roi_longitude, roi_latitude, zoom_level)

def maskS2clouds(image):
    qa = image.select('QA60')

    # Bits 10 and 11 are clouds and cirrus, respectively.
    cloudBitMask = 1 << 10
    cirrusBitMask = 1 << 11

    # Both flags should be set to zero, indicating clear conditions.
    mask = qa.bitwiseAnd(cloudBitMask).eq(0).And(qa.bitwiseAnd(cirrusBitMask).eq(0))

    return image.updateMask(mask).divide(10000)

# Load Sentinel-2 images and apply cloud masking, further we select only imagery with less than 5% cloud
dataset = (ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED')
                 .filterBounds(study_area)
                 .filterDate(start_date, end_date)
                 .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 5))
                 .map(maskS2clouds)
                 .map(lambda image: image.clip(AOI)))

# Compute the median of the image collection (this only applies to the bands (not yet NDVI or NDWI))
image_median = dataset.reduce(ee.Reducer.median())

# Function to calculate the Normalized Difference Vegetation Index (NDVI) with the NIR (B8), Red (B4)
def calculateNDVI(image):
    return image.normalizedDifference(['B8_median','B4_median']).rename('ndvi')

# Function to calculate the Normalized Difference Water Index (NDWI) with the Green (B3), Nir (B8)
def calculateNDWI(image):
    return image.normalizedDifference(['B3_median','B8_median']).rename('ndwi')

#Calculate NDVI
ndvi_image = calculateNDVI(image_median)

#Calculate NDWI
ndwi_image = calculateNDWI(image_median)

# Define visualization parameters
visualization = {
    'max': 0.3,
    'bands': ['B8_median','B4_median', 'B3_median'],
}

# Define a threshold value for NDVI to classify land areas
ndvi_threshold = 0.05
ndwi_threshold = 0

vegetation_mask = ndvi_image.lte(ndvi_threshold)
water_mask = ndwi_image.gte(ndwi_threshold)

# Combine the vegetation and water masks
combined_mask = vegetation_mask.Or(water_mask)

# Apply a median filter to the combined mask to reduce noise (adjust window size as needed)
smoothed_mask = combined_mask.focal_median(radius=4)

#image_median.addBands(ndvi_image, ndwi_image)

# Mask the land from the median composite image using the combined mask
image_median_water = image_median.updateMask(smoothed_mask)

# Add layers to the map
Map.addLayer(image_median_water, visualization, 'S2 Mask')
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[37.8, 26.8], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(…
